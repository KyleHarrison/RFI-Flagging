# %%
import pandas as pd

x = pd.read_csv('/users/kyle/CASA/M83_KAT7/GMM/catalog.csv', header = 4)

# %%
from IPython.display import display, HTML

display(x)
# Out:
#     # Gaus_id   Isl_id   Source_id   Wave_id          RA      E_RA        DEC  \
# 0           0        0           0         0  205.648100  0.002444 -29.558021
# 1           1        1           1         0  205.583728  0.002825 -30.172568
# 2           2        2           2         0  205.393871  0.002594 -29.852222
# 3           3        3           3         0  205.305569  0.004310 -30.162387
# 4           4        3           4         0  205.330497  0.005229 -30.099409
# 5           5        4           5         0  205.183986  0.001311 -30.042927
# 6           6        4           6         0  205.127839  0.002721 -30.113548
# 7           7        5           7         0  205.136436  0.001238 -30.238394
# 8           8        6           8         0  205.099861  0.004382 -30.977642
# 9           9        7           9         0  205.037377  0.004486 -30.370414
# 10         10        8          10         0  204.995282  0.001716 -29.732302
# ...
